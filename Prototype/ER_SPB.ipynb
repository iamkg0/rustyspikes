# %%
from model import *
from neurons import *
from synaptics import *
from utils import *
from protocols import *
from shallow_models import *
from vis_functions import *
res = .1

# %%
ds = delayed_3to1()
snn, delay, dd = ER_conf(ds, time=100)

# %%
ds = delayed_3to1()
snn, delay, dd = ER_conf(ds, time=200000)
time = np.arange(2000000)
plt.figure(figsize=(5,5))
#plt.xticks(np.arange(10))
plt.plot(time, np.array(delay)*.1)
plt.show()
#print(delay[:,-1])

print(dd)
plt.plot(time, dd)
plt.show()
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
snn, delay, dd = ER_conf(snn, time=100)
time = np.arange(1000)
plt.figure(figsize=(5,5))
#plt.xticks(np.arange(10))
plt.plot(time, np.array(delay)*.1)
plt.show()
#print(delay[:,-1])
plt.plot(time, dd)
plt.show()
